# %% [markdown]
# <a href="https://colab.research.google.com/github/hasanocal7/DS-Libs/blob/main/Pandas_Son_%C3%96dev.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("mpg.csv")

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
#1
df.corr()
# Out:
#                    mpg  cylinders  displacement    weight  acceleration  \
# mpg           1.000000  -0.775396     -0.804203 -0.831741      0.420289
# cylinders    -0.775396   1.000000      0.950721  0.896017     -0.505419
# displacement -0.804203   0.950721      1.000000  0.932824     -0.543684
# weight       -0.831741   0.896017      0.932824  1.000000     -0.417457
# acceleration  0.420289  -0.505419     -0.543684 -0.417457      1.000000
# model_year    0.579267  -0.348746     -0.370164 -0.306564      0.288137
# origin        0.563450  -0.562543     -0.609409 -0.581024      0.205873
#
#               model_year    origin
# mpg             0.579267  0.563450
# cylinders      -0.348746 -0.562543
# displacement   -0.370164 -0.609409
# weight         -0.306564 -0.581024
# acceleration    0.288137  0.205873
# model_year      1.000000  0.180662
# origin          0.180662  1.000000

# %%
#2
df.mpg.corr(df.model_year)
# Out:
# 0.5792671330833096

# %%
#3
df.cylinders.unique()
# Out:
# array([8, 4, 6, 3, 5])

# %%
#4
df.cylinders.value_counts()
# Out:
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
#5
df[df.model_year.between(75,80)]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 152  19.0          6         225.0         95    3264          16.0
# 153  18.0          6         250.0        105    3459          16.0
# 154  15.0          6         250.0         72    3432          21.0
# 155  15.0          6         250.0         72    3158          19.5
# 156  16.0          8         400.0        170    4668          11.5
# ..    ...        ...           ...        ...     ...           ...
# 333  32.7          6         168.0        132    2910          11.4
# 334  23.7          3          70.0        100    2420          12.5
# 335  35.0          4         122.0         88    2500          15.1
# 336  23.6          4         140.0          ?    2905          14.3
# 337  32.4          4         107.0         72    2290          17.0
#
#      model_year  origin                     name
# 152          75       1  plymouth valiant custom
# 153          75       1           chevrolet nova
# ...

# %%
#6
df.horsepower.replace('?' , np.nan , inplace = True)

# %%
df.horsepower = df.horsepower.astype(float)

# %%
df[df.horsepower.between(155,179)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 1    15.0          8         350.0       165.0    3693          11.5
# 10   15.0          8         383.0       170.0    3563          10.0
# 11   14.0          8         340.0       160.0    3609           8.0
# 38   14.0          8         350.0       165.0    4209          12.0
# 39   14.0          8         400.0       175.0    4464          11.5
# 43   13.0          8         400.0       170.0    4746          12.0
# 44   13.0          8         400.0       175.0    5140          12.0
# 62   13.0          8         350.0       165.0    4274          12.0
# 63   14.0          8         400.0       175.0    4385          12.0
# 68   13.0          8         350.0       155.0    4502          13.5
# 69   12.0          8         350.0       160.0    4456          13.5
# 85   13.0          8         350.0       175.0    4100          13.0
# 92   13.0          8         351.0       158.0    4363          13.0
# ...

# %%
#7
df = df.sort_values("horsepower" , ascending = False)

# %%
df.reset_index()
# Out:
#      index   mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0      116  16.0          8         400.0       230.0    4278           9.5
# 1       95  12.0          8         455.0       225.0    4951          11.0
# 2       13  14.0          8         455.0       225.0    3086          10.0
# 3        8  14.0          8         455.0       225.0    4425          10.0
# 4        6  14.0          8         454.0       220.0    4354           9.0
# ..     ...   ...        ...           ...         ...     ...           ...
# 393    126  21.0          6         200.0         NaN    2875          17.0
# 394    330  40.9          4          85.0         NaN    1835          17.3
# 395    336  23.6          4         140.0         NaN    2905          14.3
# 396    354  34.5          4         100.0         NaN    2320          15.8
# 397    374  23.0          4         151.0         NaN    3035          20.5
#
#      model_year  origin                      name
# ...

# %%
#8
df.sort_values("acceleration").head(5)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 11   14.0          8         340.0       160.0    3609           8.0
# 7    14.0          8         440.0       215.0    4312           8.5
# 9    15.0          8         390.0       190.0    3850           8.5
# 6    14.0          8         454.0       220.0    4354           9.0
# 116  16.0          8         400.0       230.0    4278           9.5
#
#      model_year  origin                name
# 11           70       1  plymouth 'cuda 340
# 7            70       1   plymouth fury iii
# 9            70       1  amc ambassador dpl
# 6            70       1    chevrolet impala
# 116          73       1  pontiac grand prix

# %%
df = pd.read_csv("CIA_Country_Facts.csv")

# %%
df.head()
# Out:
#           Country                               Region  Population  \
# 0     Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1         Albania  EASTERN EUROPE                          3581655
# 2         Algeria  NORTHERN AFRICA                        32930091
# 3  American Samoa  OCEANIA                                   57794
# 4         Andorra  WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# 4             468                       152.1                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
#9
df.Country.nunique()
# Out:
# 227

# %%
#10
df.isna().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy (%)                          18
# Phones (per 1000)                      4
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# Test                                  18
# dtype: int64

# %%
#11
df.dropna(how = 'all')
# Out:
#             Country                               Region  Population  \
# 0       Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1           Albania  EASTERN EUROPE                          3581655
# 2           Algeria  NORTHERN AFRICA                        32930091
# 3    American Samoa  OCEANIA                                   57794
# 4           Andorra  WESTERN EUROPE                            71201
# ..              ...                                  ...         ...
# 222       West Bank  NEAR EAST                               2460492
# 223  Western Sahara  NORTHERN AFRICA                          273008
# 224           Yemen  NEAR EAST                              21456188
# 225          Zambia  SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe  SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# ...

# %%
# 227 satır kaldığına göre tüm değerleri NaN olan bir değer yok

# %%
#12
df.groupby("Region").sum()["Population"]
# Out:
# Region
# ASIA (EX. NEAR EAST)                   3687982236
# BALTICS                                   7184974
# C.W. OF IND. STATES                     280081548
# EASTERN EUROPE                          119914717
# LATIN AMER. & CARIB                     561824599
# NEAR EAST                               195068377
# NORTHERN AFRICA                         161407133
# NORTHERN AMERICA                        331672307
# OCEANIA                                  33131662
# SUB-SAHARAN AFRICA                      749437000
# WESTERN EUROPE                          396339998
# Name: Population, dtype: int64

# %%
#13
df.Climate.fillna(df.Climate.mean() , axis = 0)
# Out:
# 0      1.0
# 1      3.0
# 2      1.0
# 3      2.0
# 4      3.0
#       ...
# 222    3.0
# 223    1.0
# 224    1.0
# 225    2.0
# 226    2.0
# Name: Climate, Length: 227, dtype: float64

# %%
#14
df.groupby(["Region" , "Country"]).sum()["Birthrate"]
# Out:
# Region                               Country
# ASIA (EX. NEAR EAST)                 Afghanistan       46.60
#                                      Bangladesh        29.80
#                                      Bhutan            33.65
#                                      Brunei            18.79
#                                      Burma             17.91
#                                                        ...
# WESTERN EUROPE                       San Marino        10.02
#                                      Spain             10.06
#                                      Sweden            10.27
#                                      Switzerland        9.71
#                                      United Kingdom    10.71
# Name: Birthrate, Length: 227, dtype: float64

# %%
#15

# %%
# Soru 1 : En Çok Ölüm Oranı Hangi Ülkede

# %%
df[df.Deathrate == df.Deathrate.max()].Country
# Out:
# 194    Swaziland
# Name: Country, dtype: object

# %%
# Soru 2 : Doğu Avrupanın En Kurak Yeri Neresi

# %%
df.groupby("Region")["Arable (%)"].min()
# Out:
# Region
# ASIA (EX. NEAR EAST)                    0.00
# BALTICS                                16.04
# C.W. OF IND. STATES                     3.72
# EASTERN EUROPE                          8.60
# LATIN AMER. & CARIB                     0.00
# NEAR EAST                               0.00
# NORTHERN AFRICA                         0.02
# NORTHERN AMERICA                        0.00
# OCEANIA                                 0.00
# SUB-SAHARAN AFRICA                      0.04
# WESTERN EUROPE                          0.00
# Name: Arable (%), dtype: float64

# %%
df[df["Arable (%)"] == df.groupby("Region")["Arable (%)"].min()[3]].Country
# Out:
# 186    Slovenia
# Name: Country, dtype: object

# %%
# Soru 3 : Refah Seviyesi En Yüksek Ülke (Bunu kişi başına düşen hasılaya (GSYİH) göre bakacağım)

# %%
df[df["GDP ($ per capita)"] == df["GDP ($ per capita)"].max()].Country
# Out:
# 121    Luxembourg
# Name: Country, dtype: object

# %%
# Soru 4 : Nüfusuna Oranla En Az Okur-Yazarlığı Olan 5 Kuzey Afrika Ülkesi

# %%
df["Test"] = np.floor(((df.Population * df["Literacy (%)"]) / 100)) / df.Population

# %%
df["Test"] = df["Test"].dropna()

# %%
df[df.Region == "NORTHERN AFRICA                    "].sort_values("Test").head(5)
# Out:
#      Country                               Region  Population  Area (sq. mi.)  \
# 141  Morocco  NORTHERN AFRICA                        33241259          446550
# 60     Egypt  NORTHERN AFRICA                        78887007         1001450
# 2    Algeria  NORTHERN AFRICA                        32930091         2381740
# 205  Tunisia  NORTHERN AFRICA                        10175014          163610
# 118    Libya  NORTHERN AFRICA                         5900754         1759540
#
#      Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  Net migration  \
# 141                        74.4                          0.41          -0.98
# 60                         78.8                          0.24          -0.22
# 2                          13.8                          0.04          -0.39
# 205                        62.2                          0.70          -0.57
# 118                         3.4                          0.10           0.00
#
# ...

# %%
# Soru 5 : Kıyı Şeridi en çok olan 3 ülke

# %%
df.sort_values("Coastline (coast/area ratio)" , ascending = False).head(3)
# Out:
#                   Country                               Region  Population  \
# 136  Micronesia, Fed. St.  OCEANIA                                  108004
# 157                 Palau  OCEANIA                                   20579
# 153    N. Mariana Islands  OCEANIA                                   82459
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 136             702                       153.9                        870.66
# 157             458                        44.9                        331.66
# 153             477                       172.9                        310.69
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 136         -20.99                               30.21              2000.0
# 157           2.85                               14.84              9000.0
# 153           9.61                                7.11             12500.0
#
# ...

# %%
# 3 ülke de Okyanusya kıtasında bulunuyor
